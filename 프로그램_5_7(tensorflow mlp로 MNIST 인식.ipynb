# %%
# 5.4.1 MNIST 인식
# 다층 퍼셉트론으로 MNIST 인식하는 [프로그램 5-7(a)]

from keras.api._v2.keras import optimizers
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train=x_train.astype(np.float32)/225.0
x_test=x_test.astype(np.float32)/255.0
y_train = tf.keras.utils.to_categorical(y_train,10)
y_test= tf.keras.utils.to_categorical(y_test,10)

n_input=784
n_hidden=1024
n_output=10

mlp=Sequential()
mlp.add(Dense(units=n_hidden, activation='tanh',input_shape=(n_input,),kernel_initializer='random_uniform', bias_initializer='zeros'))
mlp.add(Dense(units=n_output, activation='tanh', kernel_initializer='random_uniform', bias_initializer='zeros'))

mlp.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])
hist=mlp.fit(x_train, y_train, batch_size=128, epochs=30, validation_data=(x_test, y_test),verbose=2)

res=mlp.evaluate(x_test, y_test, verbose=0)
print("정확률은 ", res[1]*100)
# Out:
# Epoch 1/30
# 469/469 - 2s - loss: 0.0432 - accuracy: 0.8341 - val_loss: 0.0270 - val_accuracy: 0.9189 - 2s/epoch - 5ms/step
# Epoch 2/30
# 469/469 - 1s - loss: 0.0206 - accuracy: 0.9369 - val_loss: 0.0180 - val_accuracy: 0.9470 - 1s/epoch - 3ms/step
# Epoch 3/30
# 469/469 - 1s - loss: 0.0155 - accuracy: 0.9529 - val_loss: 0.0151 - val_accuracy: 0.9541 - 1s/epoch - 3ms/step
# Epoch 4/30
# 469/469 - 1s - loss: 0.0130 - accuracy: 0.9611 - val_loss: 0.0129 - val_accuracy: 0.9602 - 1s/epoch - 3ms/step
# Epoch 5/30
# 469/469 - 2s - loss: 0.0116 - accuracy: 0.9664 - val_loss: 0.0119 - val_accuracy: 0.9631 - 2s/epoch - 4ms/step
# Epoch 6/30
# 469/469 - 2s - loss: 0.0105 - accuracy: 0.9704 - val_loss: 0.0106 - val_accuracy: 0.9666 - 2s/epoch - 3ms/step
# Epoch 7/30
# 469/469 - 1s - loss: 0.0098 - accuracy: 0.9728 - val_loss: 0.0103 - val_accuracy: 0.9683 - 1s/epoch - 3ms/step
# Epoch 8/30
# 469/469 - 1s - loss: 0.0091 - accuracy: 0.9761 - val_loss: 0.0103 - val_accuracy: 0.9696 - 1s/epoch - 3ms/step
# Epoch 9/30
# 469/469 - 2s - loss: 0.0085 - accuracy: 0.9779 - val_loss: 0.0095 - val_accuracy: 0.9696 - 2s/epoch - 3ms/step
# Epoch 10/30
# 469/469 - 1s - loss: 0.0081 - accuracy: 0.9799 - val_loss: 0.0091 - val_accuracy: 0.9724 - 1s/epoch - 3ms/step
# Epoch 11/30
# 469/469 - 1s - loss: 0.0078 - accuracy: 0.9814 - val_loss: 0.0093 - val_accuracy: 0.9714 - 1s/epoch - 3ms/step
# Epoch 12/30
# 469/469 - 2s - loss: 0.0073 - accuracy: 0.9829 - val_loss: 0.0084 - val_accuracy: 0.9733 - 2s/epoch - 4ms/step
# Epoch 13/30
# 469/469 - 2s - loss: 0.0070 - accuracy: 0.9841 - val_loss: 0.0083 - val_accuracy: 0.9734 - 2s/epoch - 4ms/step
# Epoch 14/30
# 469/469 - 2s - loss: 0.0067 - accuracy: 0.9851 - val_loss: 0.0081 - val_accuracy: 0.9746 - 2s/epoch - 4ms/step
# Epoch 15/30
# 469/469 - 1s - loss: 0.0066 - accuracy: 0.9861 - val_loss: 0.0085 - val_accuracy: 0.9746 - 1s/epoch - 3ms/step
# Epoch 16/30
# 469/469 - 1s - loss: 0.0063 - accuracy: 0.9873 - val_loss: 0.0084 - val_accuracy: 0.9749 - 1s/epoch - 3ms/step
# Epoch 17/30
# 469/469 - 1s - loss: 0.0061 - accuracy: 0.9879 - val_loss: 0.0085 - val_accuracy: 0.9753 - 1s/epoch - 3ms/step
# Epoch 18/30
# 469/469 - 1s - loss: 0.0059 - accuracy: 0.9887 - val_loss: 0.0076 - val_accuracy: 0.9751 - 1s/epoch - 3ms/step
# Epoch 19/30
# 469/469 - 1s - loss: 0.0057 - accuracy: 0.9891 - val_loss: 0.0077 - val_accuracy: 0.9764 - 1s/epoch - 3ms/step
# Epoch 20/30
# 469/469 - 1s - loss: 0.0055 - accuracy: 0.9900 - val_loss: 0.0078 - val_accuracy: 0.9768 - 1s/epoch - 3ms/step
# Epoch 21/30
# 469/469 - 1s - loss: 0.0054 - accuracy: 0.9903 - val_loss: 0.0076 - val_accuracy: 0.9764 - 1s/epoch - 3ms/step
# Epoch 22/30
# 469/469 - 2s - loss: 0.0052 - accuracy: 0.9911 - val_loss: 0.0078 - val_accuracy: 0.9773 - 2s/epoch - 4ms/step
# Epoch 23/30
# 469/469 - 1s - loss: 0.0051 - accuracy: 0.9916 - val_loss: 0.0075 - val_accuracy: 0.9765 - 1s/epoch - 3ms/step
# Epoch 24/30
# 469/469 - 2s - loss: 0.0050 - accuracy: 0.9922 - val_loss: 0.0074 - val_accuracy: 0.9776 - 2s/epoch - 3ms/step
# Epoch 25/30
# 469/469 - 2s - loss: 0.0048 - accuracy: 0.9924 - val_loss: 0.0076 - val_accuracy: 0.9777 - 2s/epoch - 5ms/step
# Epoch 26/30
# 469/469 - 3s - loss: 0.0048 - accuracy: 0.9928 - val_loss: 0.0076 - val_accuracy: 0.9760 - 3s/epoch - 5ms/step
# Epoch 27/30
# 469/469 - 1s - loss: 0.0046 - accuracy: 0.9928 - val_loss: 0.0073 - val_accuracy: 0.9774 - 1s/epoch - 3ms/step
# Epoch 28/30
# 469/469 - 1s - loss: 0.0045 - accuracy: 0.9936 - val_loss: 0.0073 - val_accuracy: 0.9770 - 1s/epoch - 3ms/step
# Epoch 29/30
# 469/469 - 2s - loss: 0.0045 - accuracy: 0.9940 - val_loss: 0.0071 - val_accuracy: 0.9780 - 2s/epoch - 4ms/step
# Epoch 30/30
# 469/469 - 2s - loss: 0.0043 - accuracy: 0.9943 - val_loss: 0.0071 - val_accuracy: 0.9774 - 2s/epoch - 3ms/step
# 정확률은  97.7400004863739

# %%
# 5.4.2 학습 곡선 시각화
# 학습 곡선을 시각화 하는 [프로그램 5-7(b)]

from keras.api._v2.keras import optimizers
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train=x_train.astype(np.float32)/225.0
x_test=x_test.astype(np.float32)/255.0
y_train = tf.keras.utils.to_categorical(y_train,10)
y_test= tf.keras.utils.to_categorical(y_test,10)

n_input=784
n_hidden=1024
n_output=10

mlp=Sequential()
mlp.add(Dense(units=n_hidden, activation='tanh',input_shape=(n_input,),kernel_initializer='random_uniform', bias_initializer='zeros'))
mlp.add(Dense(units=n_output, activation='tanh', kernel_initializer='random_uniform', bias_initializer='zeros'))

mlp.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])
hist=mlp.fit(x_train, y_train, batch_size=128, epochs=30, validation_data=(x_test, y_test),verbose=2)

res=mlp.evaluate(x_test, y_test, verbose=0)
print("정확률은 ", res[1]*100)

import matplotlib.pyplot as plt

#정확률 곡선
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.grid()
plt.show()

#손실함수 곡선
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.grid()
plt.show()
# Out:
# Epoch 1/30
# 469/469 - 3s - loss: 0.0420 - accuracy: 0.8531 - val_loss: 0.0272 - val_accuracy: 0.9162 - 3s/epoch - 6ms/step
# Epoch 2/30
# 469/469 - 1s - loss: 0.0213 - accuracy: 0.9341 - val_loss: 0.0187 - val_accuracy: 0.9418 - 1s/epoch - 3ms/step
# Epoch 3/30
# 469/469 - 1s - loss: 0.0159 - accuracy: 0.9509 - val_loss: 0.0150 - val_accuracy: 0.9524 - 1s/epoch - 3ms/step
# Epoch 4/30
# 469/469 - 1s - loss: 0.0134 - accuracy: 0.9599 - val_loss: 0.0132 - val_accuracy: 0.9591 - 1s/epoch - 3ms/step
# Epoch 5/30
# 469/469 - 2s - loss: 0.0118 - accuracy: 0.9662 - val_loss: 0.0115 - val_accuracy: 0.9637 - 2s/epoch - 3ms/step
# Epoch 6/30
# 469/469 - 2s - loss: 0.0107 - accuracy: 0.9697 - val_loss: 0.0107 - val_accuracy: 0.9679 - 2s/epoch - 4ms/step
# Epoch 7/30
# 469/469 - 3s - loss: 0.0098 - accuracy: 0.9733 - val_loss: 0.0103 - val_accuracy: 0.9675 - 3s/epoch - 6ms/step
# Epoch 8/30
# 469/469 - 3s - loss: 0.0092 - accuracy: 0.9750 - val_loss: 0.0100 - val_accuracy: 0.9702 - 3s/epoch - 6ms/step
# Epoch 9/30
# 469/469 - 2s - loss: 0.0087 - accuracy: 0.9773 - val_loss: 0.0097 - val_accuracy: 0.9706 - 2s/epoch - 4ms/step
# Epoch 10/30
# 469/469 - 1s - loss: 0.0082 - accuracy: 0.9793 - val_loss: 0.0094 - val_accuracy: 0.9717 - 1s/epoch - 3ms/step
# Epoch 11/30
# 469/469 - 1s - loss: 0.0077 - accuracy: 0.9806 - val_loss: 0.0090 - val_accuracy: 0.9722 - 1s/epoch - 3ms/step
# Epoch 12/30
# 469/469 - 1s - loss: 0.0074 - accuracy: 0.9824 - val_loss: 0.0086 - val_accuracy: 0.9723 - 1s/epoch - 3ms/step
# Epoch 13/30
# 469/469 - 1s - loss: 0.0071 - accuracy: 0.9835 - val_loss: 0.0087 - val_accuracy: 0.9729 - 1s/epoch - 3ms/step
# Epoch 14/30
# 469/469 - 2s - loss: 0.0068 - accuracy: 0.9845 - val_loss: 0.0086 - val_accuracy: 0.9745 - 2s/epoch - 4ms/step
# Epoch 15/30
# 469/469 - 2s - loss: 0.0067 - accuracy: 0.9854 - val_loss: 0.0081 - val_accuracy: 0.9745 - 2s/epoch - 4ms/step
# Epoch 16/30
# 469/469 - 1s - loss: 0.0064 - accuracy: 0.9861 - val_loss: 0.0081 - val_accuracy: 0.9741 - 1s/epoch - 3ms/step
# Epoch 17/30
# 469/469 - 1s - loss: 0.0062 - accuracy: 0.9870 - val_loss: 0.0083 - val_accuracy: 0.9754 - 1s/epoch - 3ms/step
# Epoch 18/30
# 469/469 - 1s - loss: 0.0060 - accuracy: 0.9876 - val_loss: 0.0079 - val_accuracy: 0.9747 - 1s/epoch - 3ms/step
# Epoch 19/30
# 469/469 - 1s - loss: 0.0058 - accuracy: 0.9886 - val_loss: 0.0079 - val_accuracy: 0.9750 - 1s/epoch - 3ms/step
# Epoch 20/30
# 469/469 - 1s - loss: 0.0056 - accuracy: 0.9891 - val_loss: 0.0080 - val_accuracy: 0.9770 - 1s/epoch - 3ms/step
# Epoch 21/30
# 469/469 - 1s - loss: 0.0054 - accuracy: 0.9898 - val_loss: 0.0078 - val_accuracy: 0.9761 - 1s/epoch - 3ms/step
# Epoch 22/30
# 469/469 - 1s - loss: 0.0053 - accuracy: 0.9907 - val_loss: 0.0077 - val_accuracy: 0.9766 - 1s/epoch - 3ms/step
# Epoch 23/30
# 469/469 - 2s - loss: 0.0052 - accuracy: 0.9909 - val_loss: 0.0075 - val_accuracy: 0.9764 - 2s/epoch - 4ms/step
# Epoch 24/30
# 469/469 - 1s - loss: 0.0050 - accuracy: 0.9916 - val_loss: 0.0074 - val_accuracy: 0.9773 - 1s/epoch - 3ms/step
# Epoch 25/30
# 469/469 - 1s - loss: 0.0049 - accuracy: 0.9919 - val_loss: 0.0073 - val_accuracy: 0.9773 - 1s/epoch - 3ms/step
# Epoch 26/30
# 469/469 - 1s - loss: 0.0048 - accuracy: 0.9921 - val_loss: 0.0072 - val_accuracy: 0.9769 - 1s/epoch - 3ms/step
# Epoch 27/30
# 469/469 - 1s - loss: 0.0047 - accuracy: 0.9926 - val_loss: 0.0073 - val_accuracy: 0.9772 - 1s/epoch - 3ms/step
# Epoch 28/30
# 469/469 - 2s - loss: 0.0046 - accuracy: 0.9929 - val_loss: 0.0072 - val_accuracy: 0.9779 - 2s/epoch - 4ms/step
# Epoch 29/30
# 469/469 - 1s - loss: 0.0045 - accuracy: 0.9933 - val_loss: 0.0076 - val_accuracy: 0.9768 - 1s/epoch - 3ms/step
# Epoch 30/30
# 469/469 - 1s - loss: 0.0044 - accuracy: 0.9934 - val_loss: 0.0074 - val_accuracy: 0.9774 - 1s/epoch - 3ms/step
# 정확률은  97.7400004863739
